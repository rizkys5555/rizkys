# %% [markdown]
# Introduction
# This notebook serves as the final assignment for the data science course, demonstrating proficiency in key tools and concepts. It includes sections on programming languages, libraries, data science tools, and basic arithmetic and conversion exercises, as outlined in the project guidelines.

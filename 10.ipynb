# %% [markdown]
# Objectives
# Understand and utilize Jupyter Notebook for data science tasks.
# Gain familiarity with core data science languages and libraries.
# Practice creating both Markdown and Code cells effectively.
# Complete practical programming exercises involving arithmetic and data manipulation.

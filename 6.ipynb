# %% [markdown]
# Table of Data Science Tools
# Category	Tool	Description
# Notebook Environment	Jupyter Notebook	Interactive environment for code, text, and visualization.
# Version Control	GitHub	Web-based hosting service for version control using Git.
# Visualization	Tableau / Power BI	Business intelligence and data visualization tools.
# Big Data Framework	Apache Spark	Fast and general-purpose cluster computing system for large datasets.
# Cloud Services	AWS, Azure, GCP	Cloud platforms offering a wide range of data science tools and infrastructure.

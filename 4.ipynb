# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Scala
# 5. Java
# 6. C++
# 7. Julia
# 8. Javascript
# 9. Php
# 10. Go
# 11. Ruby
# 12. Visual Basic

# %%
# This is a code cell
# Define variables
a = 5
b = 10
c = 2
# Perform operations
multiplication_result = a * b
addition_result = b + c
# Print the results
print(f"Multiplication result (a * b): {multiplication_result}")
print(f"Addition result (b + c): {addition_result}")
# Out:
# Multiplication result (a * b): 50
# Addition result (b + c): 12

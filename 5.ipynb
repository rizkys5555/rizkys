# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. Numpy
# 3. Matplotlib
# 4. Seaborn
# 5. Scikit-learn
# 6. Keras
# 7. TensorFlow
# 8. PyTorch
# 9. Apache Spark
# 10. Vegas
# 11. Big DL
# 12. Ggplot2
